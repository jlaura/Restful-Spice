# %%
import json

import pvl
import requests

# %% [markdown]
# ## Create the necessary input data
#
# To create an ISD we require the following:
#
# - target_name, e.g. Mercury
# - capture_date (PDS data product dates appear to be ISO 8601 compliant)
# - instrument, e.g. mdis-nac
# - focal_plane_temperature (optionally included for temperature dependent focal lengths)
# - spacecraft_id, e.g. messenger
# - spacecraft_clock_count, from the label
# - exposure_duration, from the label
# - lighttime_correction, to tell spice what to use
# - min_elevation (make optional?)
# - max_elevation (make optional?)
#
# For the last two, it might be easier/better to take the intital center point from the PDS label and hit a low res. DEM to find these automatically for the user.

# %%
label = pvl.load('/data/cassini/iss/N1829241514_1.LBL')
data = {'target_name': label['TARGET_NAME'],
        'capture_date': label['START_TIME'].isoformat(),
        'instrument': label['INSTRUMENT_NAME'], 
        'spacecraft_id' : label['INSTRUMENT_HOST_NAME'],
        'spacecraft_clock_count': label['SPACECRAFT_CLOCK_START_COUNT'],
        'exposure_duration': label['EXPOSURE_DURATION'],
        'lighttime_correction':'LT+S', 
        'min_elevation': -100,
        'max_elevation': 100
        }
import json
data = json.dumps(data)

# %%
data
# Out:
# '{"target_name": "ENCELADUS", "capture_date": "2015-12-19T17:34:38.317000", "instrument": "IMAGING SCIENCE SUBSYSTEM - NARROW ANGLE", "spacecraft_id": "CASSINI ORBITER", "spacecraft_clock_count": "1829241512.246", "exposure_duration": 1500.0, "lighttime_correction": "LT+S", "min_elevation": -100, "max_elevation": 100}'

# %% [markdown]
# ## Standard API landing page

# %%
r = requests.get('http://smalls:8002/api/1.0/')
r.json()
# Out:
# {'data': {'urls': {'missions': '/api/1.0/missions.'}}, 'success': True}

# %% [markdown]
# ## Pushing the API into a namespace and versioning is good practice

# %%
r = requests.get('http://smalls:8002/api/1.0')
r.json()
# Out:
# {'data': {'urls': {'missions': '/api/1.0/missions.'}}, 'success': True}

# %% [markdown]
# ## Example listing of the kernels

# %%
r = requests.get('http://smalls:8002/api/1.0/missions/cassini/metakernels')
r.json()
# Out:
# {'data': [{'id': 227,
#    'mission': 'cassini',
#    'name': 'cas_1997_v21.tm',
#    'newest': True,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1997_v21.tm',
#    'year': '1997-01-01'},
#   {'id': 228,
#    'mission': 'cassini',
#    'name': 'cas_1997_v20.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1997_v20.tm',
#    'year': '1997-01-01'},
#   {'id': 229,
#    'mission': 'cassini',
#    'name': 'cas_1997_v19.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1997_v19.tm',
#    'year': '1997-01-01'},
#   {'id': 230,
#    'mission': 'cassini',
#    'name': 'cas_1997_v18.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1997_v18.tm',
#    'year': '1997-01-01'},
#   {'id': 231,
#    'mission': 'cassini',
#    'name': 'cas_1997_v17.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1997_v17.tm',
#    'year': '1997-01-01'},
#   {'id': 232,
#    'mission': 'cassini',
#    'name': 'cas_1997_v16.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1997_v16.tm',
#    'year': '1997-01-01'},
#   {'id': 233,
#    'mission': 'cassini',
#    'name': 'cas_1997_v15.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1997_v15.tm',
#    'year': '1997-01-01'},
#   {'id': 234,
#    'mission': 'cassini',
#    'name': 'cas_1997_v14.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1997_v14.tm',
#    'year': '1997-01-01'},
#   {'id': 235,
#    'mission': 'cassini',
#    'name': 'cas_1997_v13.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1997_v13.tm',
#    'year': '1997-01-01'},
#   {'id': 236,
#    'mission': 'cassini',
#    'name': 'cas_1997_v12.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1997_v12.tm',
#    'year': '1997-01-01'},
#   {'id': 237,
#    'mission': 'cassini',
#    'name': 'cas_1997_v11.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1997_v11.tm',
#    'year': '1997-01-01'},
#   {'id': 238,
#    'mission': 'cassini',
#    'name': 'cas_1997_v10.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1997_v10.tm',
#    'year': '1997-01-01'},
#   {'id': 239,
#    'mission': 'cassini',
#    'name': 'cas_1997_v09.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1997_v09.tm',
#    'year': '1997-01-01'},
#   {'id': 240,
#    'mission': 'cassini',
#    'name': 'cas_1997_v08.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1997_v08.tm',
#    'year': '1997-01-01'},
#   {'id': 241,
#    'mission': 'cassini',
#    'name': 'cas_1997_v07.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1997_v07.tm',
#    'year': '1997-01-01'},
#   {'id': 242,
#    'mission': 'cassini',
#    'name': 'cas_1997_v06.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1997_v06.tm',
#    'year': '1997-01-01'},
#   {'id': 243,
#    'mission': 'cassini',
#    'name': 'cas_1997_v05.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1997_v05.tm',
#    'year': '1997-01-01'},
#   {'id': 244,
#    'mission': 'cassini',
#    'name': 'cas_1997_v04.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1997_v04.tm',
#    'year': '1997-01-01'},
#   {'id': 245,
#    'mission': 'cassini',
#    'name': 'cas_1997_v03.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1997_v03.tm',
#    'year': '1997-01-01'},
#   {'id': 246,
#    'mission': 'cassini',
#    'name': 'cas_1997_v02.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1997_v02.tm',
#    'year': '1997-01-01'},
#   {'id': 247,
#    'mission': 'cassini',
#    'name': 'cas_1997_v01.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1997_v01.tm',
#    'year': '1997-01-01'},
#   {'id': 248,
#    'mission': 'cassini',
#    'name': 'cas_2009_v18.tm',
#    'newest': True,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2009_v18.tm',
#    'year': '2009-01-01'},
#   {'id': 249,
#    'mission': 'cassini',
#    'name': 'cas_2009_v17.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2009_v17.tm',
#    'year': '2009-01-01'},
#   {'id': 250,
#    'mission': 'cassini',
#    'name': 'cas_2009_v16.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2009_v16.tm',
#    'year': '2009-01-01'},
#   {'id': 251,
#    'mission': 'cassini',
#    'name': 'cas_2009_v15.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2009_v15.tm',
#    'year': '2009-01-01'},
#   {'id': 252,
#    'mission': 'cassini',
#    'name': 'cas_2009_v14.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2009_v14.tm',
#    'year': '2009-01-01'},
#   {'id': 253,
#    'mission': 'cassini',
#    'name': 'cas_2009_v13.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2009_v13.tm',
#    'year': '2009-01-01'},
#   {'id': 254,
#    'mission': 'cassini',
#    'name': 'cas_2009_v12.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2009_v12.tm',
#    'year': '2009-01-01'},
#   {'id': 255,
#    'mission': 'cassini',
#    'name': 'cas_2009_v11.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2009_v11.tm',
#    'year': '2009-01-01'},
#   {'id': 256,
#    'mission': 'cassini',
#    'name': 'cas_2009_v10.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2009_v10.tm',
#    'year': '2009-01-01'},
#   {'id': 257,
#    'mission': 'cassini',
#    'name': 'cas_2009_v09.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2009_v09.tm',
#    'year': '2009-01-01'},
#   {'id': 258,
#    'mission': 'cassini',
#    'name': 'cas_2009_v08.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2009_v08.tm',
#    'year': '2009-01-01'},
#   {'id': 259,
#    'mission': 'cassini',
#    'name': 'cas_2009_v07.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2009_v07.tm',
#    'year': '2009-01-01'},
#   {'id': 260,
#    'mission': 'cassini',
#    'name': 'cas_2009_v06.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2009_v06.tm',
#    'year': '2009-01-01'},
#   {'id': 261,
#    'mission': 'cassini',
#    'name': 'cas_2009_v05.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2009_v05.tm',
#    'year': '2009-01-01'},
#   {'id': 262,
#    'mission': 'cassini',
#    'name': 'cas_2009_v04.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2009_v04.tm',
#    'year': '2009-01-01'},
#   {'id': 263,
#    'mission': 'cassini',
#    'name': 'cas_2009_v03.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2009_v03.tm',
#    'year': '2009-01-01'},
#   {'id': 264,
#    'mission': 'cassini',
#    'name': 'cas_2009_v02.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2009_v02.tm',
#    'year': '2009-01-01'},
#   {'id': 265,
#    'mission': 'cassini',
#    'name': 'cas_2009_v01.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2009_v01.tm',
#    'year': '2009-01-01'},
#   {'id': 266,
#    'mission': 'cassini',
#    'name': 'cas_2013_v11.tm',
#    'newest': True,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2013_v11.tm',
#    'year': '2013-01-01'},
#   {'id': 267,
#    'mission': 'cassini',
#    'name': 'cas_2013_v10.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2013_v10.tm',
#    'year': '2013-01-01'},
#   {'id': 268,
#    'mission': 'cassini',
#    'name': 'cas_2013_v09.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2013_v09.tm',
#    'year': '2013-01-01'},
#   {'id': 269,
#    'mission': 'cassini',
#    'name': 'cas_2013_v08.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2013_v08.tm',
#    'year': '2013-01-01'},
#   {'id': 270,
#    'mission': 'cassini',
#    'name': 'cas_2013_v07.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2013_v07.tm',
#    'year': '2013-01-01'},
#   {'id': 271,
#    'mission': 'cassini',
#    'name': 'cas_2013_v06.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2013_v06.tm',
#    'year': '2013-01-01'},
#   {'id': 272,
#    'mission': 'cassini',
#    'name': 'cas_2013_v05.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2013_v05.tm',
#    'year': '2013-01-01'},
#   {'id': 273,
#    'mission': 'cassini',
#    'name': 'cas_2013_v04.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2013_v04.tm',
#    'year': '2013-01-01'},
#   {'id': 274,
#    'mission': 'cassini',
#    'name': 'cas_2013_v03.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2013_v03.tm',
#    'year': '2013-01-01'},
#   {'id': 275,
#    'mission': 'cassini',
#    'name': 'cas_2013_v02.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2013_v02.tm',
#    'year': '2013-01-01'},
#   {'id': 276,
#    'mission': 'cassini',
#    'name': 'cas_2013_v01.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2013_v01.tm',
#    'year': '2013-01-01'},
#   {'id': 277,
#    'mission': 'cassini',
#    'name': 'cas_2005_v26.tm',
#    'newest': True,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v26.tm',
#    'year': '2005-01-01'},
#   {'id': 278,
#    'mission': 'cassini',
#    'name': 'cas_2005_v25.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v25.tm',
#    'year': '2005-01-01'},
#   {'id': 279,
#    'mission': 'cassini',
#    'name': 'cas_2005_v24.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v24.tm',
#    'year': '2005-01-01'},
#   {'id': 280,
#    'mission': 'cassini',
#    'name': 'cas_2005_v23.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v23.tm',
#    'year': '2005-01-01'},
#   {'id': 281,
#    'mission': 'cassini',
#    'name': 'cas_2005_v22.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v22.tm',
#    'year': '2005-01-01'},
#   {'id': 282,
#    'mission': 'cassini',
#    'name': 'cas_2005_v21.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v21.tm',
#    'year': '2005-01-01'},
#   {'id': 283,
#    'mission': 'cassini',
#    'name': 'cas_2005_v20.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v20.tm',
#    'year': '2005-01-01'},
#   {'id': 284,
#    'mission': 'cassini',
#    'name': 'cas_2005_v19.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v19.tm',
#    'year': '2005-01-01'},
#   {'id': 285,
#    'mission': 'cassini',
#    'name': 'cas_2005_v18.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v18.tm',
#    'year': '2005-01-01'},
#   {'id': 286,
#    'mission': 'cassini',
#    'name': 'cas_2005_v17.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v17.tm',
#    'year': '2005-01-01'},
#   {'id': 287,
#    'mission': 'cassini',
#    'name': 'cas_2005_v16.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v16.tm',
#    'year': '2005-01-01'},
#   {'id': 288,
#    'mission': 'cassini',
#    'name': 'cas_2005_v15.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v15.tm',
#    'year': '2005-01-01'},
#   {'id': 289,
#    'mission': 'cassini',
#    'name': 'cas_2005_v14.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v14.tm',
#    'year': '2005-01-01'},
#   {'id': 290,
#    'mission': 'cassini',
#    'name': 'cas_2005_v13.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v13.tm',
#    'year': '2005-01-01'},
#   {'id': 291,
#    'mission': 'cassini',
#    'name': 'cas_2005_v12.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v12.tm',
#    'year': '2005-01-01'},
#   {'id': 292,
#    'mission': 'cassini',
#    'name': 'cas_2005_v11.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v11.tm',
#    'year': '2005-01-01'},
#   {'id': 293,
#    'mission': 'cassini',
#    'name': 'cas_2005_v10.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v10.tm',
#    'year': '2005-01-01'},
#   {'id': 294,
#    'mission': 'cassini',
#    'name': 'cas_2005_v09.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v09.tm',
#    'year': '2005-01-01'},
#   {'id': 295,
#    'mission': 'cassini',
#    'name': 'cas_2005_v08.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v08.tm',
#    'year': '2005-01-01'},
#   {'id': 296,
#    'mission': 'cassini',
#    'name': 'cas_2005_v07.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v07.tm',
#    'year': '2005-01-01'},
#   {'id': 297,
#    'mission': 'cassini',
#    'name': 'cas_2005_v06.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v06.tm',
#    'year': '2005-01-01'},
#   {'id': 298,
#    'mission': 'cassini',
#    'name': 'cas_2005_v05.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v05.tm',
#    'year': '2005-01-01'},
#   {'id': 299,
#    'mission': 'cassini',
#    'name': 'cas_2005_v04.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v04.tm',
#    'year': '2005-01-01'},
#   {'id': 300,
#    'mission': 'cassini',
#    'name': 'cas_2005_v03.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v03.tm',
#    'year': '2005-01-01'},
#   {'id': 301,
#    'mission': 'cassini',
#    'name': 'cas_2005_v02.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v02.tm',
#    'year': '2005-01-01'},
#   {'id': 302,
#    'mission': 'cassini',
#    'name': 'cas_2005_v01.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2005_v01.tm',
#    'year': '2005-01-01'},
#   {'id': 303,
#    'mission': 'cassini',
#    'name': 'cas_2003_v25.tm',
#    'newest': True,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v25.tm',
#    'year': '2003-01-01'},
#   {'id': 304,
#    'mission': 'cassini',
#    'name': 'cas_2003_v24.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v24.tm',
#    'year': '2003-01-01'},
#   {'id': 305,
#    'mission': 'cassini',
#    'name': 'cas_2003_v23.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v23.tm',
#    'year': '2003-01-01'},
#   {'id': 306,
#    'mission': 'cassini',
#    'name': 'cas_2003_v22.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v22.tm',
#    'year': '2003-01-01'},
#   {'id': 307,
#    'mission': 'cassini',
#    'name': 'cas_2003_v21.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v21.tm',
#    'year': '2003-01-01'},
#   {'id': 308,
#    'mission': 'cassini',
#    'name': 'cas_2003_v20.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v20.tm',
#    'year': '2003-01-01'},
#   {'id': 309,
#    'mission': 'cassini',
#    'name': 'cas_2003_v19.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v19.tm',
#    'year': '2003-01-01'},
#   {'id': 310,
#    'mission': 'cassini',
#    'name': 'cas_2003_v18.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v18.tm',
#    'year': '2003-01-01'},
#   {'id': 311,
#    'mission': 'cassini',
#    'name': 'cas_2003_v17.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v17.tm',
#    'year': '2003-01-01'},
#   {'id': 312,
#    'mission': 'cassini',
#    'name': 'cas_2003_v16.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v16.tm',
#    'year': '2003-01-01'},
#   {'id': 313,
#    'mission': 'cassini',
#    'name': 'cas_2003_v15.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v15.tm',
#    'year': '2003-01-01'},
#   {'id': 314,
#    'mission': 'cassini',
#    'name': 'cas_2003_v14.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v14.tm',
#    'year': '2003-01-01'},
#   {'id': 315,
#    'mission': 'cassini',
#    'name': 'cas_2003_v13.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v13.tm',
#    'year': '2003-01-01'},
#   {'id': 316,
#    'mission': 'cassini',
#    'name': 'cas_2003_v12.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v12.tm',
#    'year': '2003-01-01'},
#   {'id': 317,
#    'mission': 'cassini',
#    'name': 'cas_2003_v11.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v11.tm',
#    'year': '2003-01-01'},
#   {'id': 318,
#    'mission': 'cassini',
#    'name': 'cas_2003_v10.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v10.tm',
#    'year': '2003-01-01'},
#   {'id': 319,
#    'mission': 'cassini',
#    'name': 'cas_2003_v09.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v09.tm',
#    'year': '2003-01-01'},
#   {'id': 320,
#    'mission': 'cassini',
#    'name': 'cas_2003_v08.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v08.tm',
#    'year': '2003-01-01'},
#   {'id': 321,
#    'mission': 'cassini',
#    'name': 'cas_2003_v07.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v07.tm',
#    'year': '2003-01-01'},
#   {'id': 322,
#    'mission': 'cassini',
#    'name': 'cas_2003_v06.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v06.tm',
#    'year': '2003-01-01'},
#   {'id': 323,
#    'mission': 'cassini',
#    'name': 'cas_2003_v05.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v05.tm',
#    'year': '2003-01-01'},
#   {'id': 324,
#    'mission': 'cassini',
#    'name': 'cas_2003_v04.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v04.tm',
#    'year': '2003-01-01'},
#   {'id': 325,
#    'mission': 'cassini',
#    'name': 'cas_2003_v03.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v03.tm',
#    'year': '2003-01-01'},
#   {'id': 326,
#    'mission': 'cassini',
#    'name': 'cas_2003_v02.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v02.tm',
#    'year': '2003-01-01'},
#   {'id': 327,
#    'mission': 'cassini',
#    'name': 'cas_2003_v01.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2003_v01.tm',
#    'year': '2003-01-01'},
#   {'id': 328,
#    'mission': 'cassini',
#    'name': 'cas_2008_v21.tm',
#    'newest': True,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2008_v21.tm',
#    'year': '2008-01-01'},
#   {'id': 329,
#    'mission': 'cassini',
#    'name': 'cas_2008_v20.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2008_v20.tm',
#    'year': '2008-01-01'},
#   {'id': 330,
#    'mission': 'cassini',
#    'name': 'cas_2008_v19.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2008_v19.tm',
#    'year': '2008-01-01'},
#   {'id': 331,
#    'mission': 'cassini',
#    'name': 'cas_2008_v18.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2008_v18.tm',
#    'year': '2008-01-01'},
#   {'id': 332,
#    'mission': 'cassini',
#    'name': 'cas_2008_v17.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2008_v17.tm',
#    'year': '2008-01-01'},
#   {'id': 333,
#    'mission': 'cassini',
#    'name': 'cas_2008_v16.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2008_v16.tm',
#    'year': '2008-01-01'},
#   {'id': 334,
#    'mission': 'cassini',
#    'name': 'cas_2008_v15.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2008_v15.tm',
#    'year': '2008-01-01'},
#   {'id': 335,
#    'mission': 'cassini',
#    'name': 'cas_2008_v14.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2008_v14.tm',
#    'year': '2008-01-01'},
#   {'id': 336,
#    'mission': 'cassini',
#    'name': 'cas_2008_v13.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2008_v13.tm',
#    'year': '2008-01-01'},
#   {'id': 337,
#    'mission': 'cassini',
#    'name': 'cas_2008_v12.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2008_v12.tm',
#    'year': '2008-01-01'},
#   {'id': 338,
#    'mission': 'cassini',
#    'name': 'cas_2008_v11.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2008_v11.tm',
#    'year': '2008-01-01'},
#   {'id': 339,
#    'mission': 'cassini',
#    'name': 'cas_2008_v10.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2008_v10.tm',
#    'year': '2008-01-01'},
#   {'id': 340,
#    'mission': 'cassini',
#    'name': 'cas_2008_v09.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2008_v09.tm',
#    'year': '2008-01-01'},
#   {'id': 341,
#    'mission': 'cassini',
#    'name': 'cas_2008_v08.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2008_v08.tm',
#    'year': '2008-01-01'},
#   {'id': 342,
#    'mission': 'cassini',
#    'name': 'cas_2008_v07.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2008_v07.tm',
#    'year': '2008-01-01'},
#   {'id': 343,
#    'mission': 'cassini',
#    'name': 'cas_2008_v06.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2008_v06.tm',
#    'year': '2008-01-01'},
#   {'id': 344,
#    'mission': 'cassini',
#    'name': 'cas_2008_v05.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2008_v05.tm',
#    'year': '2008-01-01'},
#   {'id': 345,
#    'mission': 'cassini',
#    'name': 'cas_2008_v04.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2008_v04.tm',
#    'year': '2008-01-01'},
#   {'id': 346,
#    'mission': 'cassini',
#    'name': 'cas_2008_v03.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2008_v03.tm',
#    'year': '2008-01-01'},
#   {'id': 347,
#    'mission': 'cassini',
#    'name': 'cas_2008_v02.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2008_v02.tm',
#    'year': '2008-01-01'},
#   {'id': 348,
#    'mission': 'cassini',
#    'name': 'cas_2008_v01.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2008_v01.tm',
#    'year': '2008-01-01'},
#   {'id': 349,
#    'mission': 'cassini',
#    'name': 'cas_2007_v23.tm',
#    'newest': True,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2007_v23.tm',
#    'year': '2007-01-01'},
#   {'id': 350,
#    'mission': 'cassini',
#    'name': 'cas_2007_v22.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2007_v22.tm',
#    'year': '2007-01-01'},
#   {'id': 351,
#    'mission': 'cassini',
#    'name': 'cas_2007_v21.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2007_v21.tm',
#    'year': '2007-01-01'},
#   {'id': 352,
#    'mission': 'cassini',
#    'name': 'cas_2007_v20.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2007_v20.tm',
#    'year': '2007-01-01'},
#   {'id': 353,
#    'mission': 'cassini',
#    'name': 'cas_2007_v19.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2007_v19.tm',
#    'year': '2007-01-01'},
#   {'id': 354,
#    'mission': 'cassini',
#    'name': 'cas_2007_v18.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2007_v18.tm',
#    'year': '2007-01-01'},
#   {'id': 355,
#    'mission': 'cassini',
#    'name': 'cas_2007_v17.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2007_v17.tm',
#    'year': '2007-01-01'},
#   {'id': 356,
#    'mission': 'cassini',
#    'name': 'cas_2007_v16.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2007_v16.tm',
#    'year': '2007-01-01'},
#   {'id': 357,
#    'mission': 'cassini',
#    'name': 'cas_2007_v15.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2007_v15.tm',
#    'year': '2007-01-01'},
#   {'id': 358,
#    'mission': 'cassini',
#    'name': 'cas_2007_v14.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2007_v14.tm',
#    'year': '2007-01-01'},
#   {'id': 359,
#    'mission': 'cassini',
#    'name': 'cas_2007_v13.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2007_v13.tm',
#    'year': '2007-01-01'},
#   {'id': 360,
#    'mission': 'cassini',
#    'name': 'cas_2007_v12.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2007_v12.tm',
#    'year': '2007-01-01'},
#   {'id': 361,
#    'mission': 'cassini',
#    'name': 'cas_2007_v11.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2007_v11.tm',
#    'year': '2007-01-01'},
#   {'id': 362,
#    'mission': 'cassini',
#    'name': 'cas_2007_v10.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2007_v10.tm',
#    'year': '2007-01-01'},
#   {'id': 363,
#    'mission': 'cassini',
#    'name': 'cas_2007_v09.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2007_v09.tm',
#    'year': '2007-01-01'},
#   {'id': 364,
#    'mission': 'cassini',
#    'name': 'cas_2007_v08.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2007_v08.tm',
#    'year': '2007-01-01'},
#   {'id': 365,
#    'mission': 'cassini',
#    'name': 'cas_2007_v07.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2007_v07.tm',
#    'year': '2007-01-01'},
#   {'id': 366,
#    'mission': 'cassini',
#    'name': 'cas_2007_v06.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2007_v06.tm',
#    'year': '2007-01-01'},
#   {'id': 367,
#    'mission': 'cassini',
#    'name': 'cas_2007_v05.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2007_v05.tm',
#    'year': '2007-01-01'},
#   {'id': 368,
#    'mission': 'cassini',
#    'name': 'cas_2007_v04.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2007_v04.tm',
#    'year': '2007-01-01'},
#   {'id': 369,
#    'mission': 'cassini',
#    'name': 'cas_2007_v03.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2007_v03.tm',
#    'year': '2007-01-01'},
#   {'id': 370,
#    'mission': 'cassini',
#    'name': 'cas_2007_v02.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2007_v02.tm',
#    'year': '2007-01-01'},
#   {'id': 371,
#    'mission': 'cassini',
#    'name': 'cas_2007_v01.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2007_v01.tm',
#    'year': '2007-01-01'},
#   {'id': 372,
#    'mission': 'cassini',
#    'name': 'cas_2004_v25.tm',
#    'newest': True,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v25.tm',
#    'year': '2004-01-01'},
#   {'id': 373,
#    'mission': 'cassini',
#    'name': 'cas_2004_v24.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v24.tm',
#    'year': '2004-01-01'},
#   {'id': 374,
#    'mission': 'cassini',
#    'name': 'cas_2004_v23.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v23.tm',
#    'year': '2004-01-01'},
#   {'id': 375,
#    'mission': 'cassini',
#    'name': 'cas_2004_v22.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v22.tm',
#    'year': '2004-01-01'},
#   {'id': 376,
#    'mission': 'cassini',
#    'name': 'cas_2004_v21.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v21.tm',
#    'year': '2004-01-01'},
#   {'id': 377,
#    'mission': 'cassini',
#    'name': 'cas_2004_v20.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v20.tm',
#    'year': '2004-01-01'},
#   {'id': 378,
#    'mission': 'cassini',
#    'name': 'cas_2004_v19.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v19.tm',
#    'year': '2004-01-01'},
#   {'id': 379,
#    'mission': 'cassini',
#    'name': 'cas_2004_v18.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v18.tm',
#    'year': '2004-01-01'},
#   {'id': 380,
#    'mission': 'cassini',
#    'name': 'cas_2004_v17.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v17.tm',
#    'year': '2004-01-01'},
#   {'id': 381,
#    'mission': 'cassini',
#    'name': 'cas_2004_v16.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v16.tm',
#    'year': '2004-01-01'},
#   {'id': 382,
#    'mission': 'cassini',
#    'name': 'cas_2004_v15.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v15.tm',
#    'year': '2004-01-01'},
#   {'id': 383,
#    'mission': 'cassini',
#    'name': 'cas_2004_v14.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v14.tm',
#    'year': '2004-01-01'},
#   {'id': 384,
#    'mission': 'cassini',
#    'name': 'cas_2004_v13.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v13.tm',
#    'year': '2004-01-01'},
#   {'id': 385,
#    'mission': 'cassini',
#    'name': 'cas_2004_v12.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v12.tm',
#    'year': '2004-01-01'},
#   {'id': 386,
#    'mission': 'cassini',
#    'name': 'cas_2004_v11.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v11.tm',
#    'year': '2004-01-01'},
#   {'id': 387,
#    'mission': 'cassini',
#    'name': 'cas_2004_v10.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v10.tm',
#    'year': '2004-01-01'},
#   {'id': 388,
#    'mission': 'cassini',
#    'name': 'cas_2004_v09.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v09.tm',
#    'year': '2004-01-01'},
#   {'id': 389,
#    'mission': 'cassini',
#    'name': 'cas_2004_v08.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v08.tm',
#    'year': '2004-01-01'},
#   {'id': 390,
#    'mission': 'cassini',
#    'name': 'cas_2004_v07.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v07.tm',
#    'year': '2004-01-01'},
#   {'id': 391,
#    'mission': 'cassini',
#    'name': 'cas_2004_v06.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v06.tm',
#    'year': '2004-01-01'},
#   {'id': 392,
#    'mission': 'cassini',
#    'name': 'cas_2004_v05.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v05.tm',
#    'year': '2004-01-01'},
#   {'id': 393,
#    'mission': 'cassini',
#    'name': 'cas_2004_v04.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v04.tm',
#    'year': '2004-01-01'},
#   {'id': 394,
#    'mission': 'cassini',
#    'name': 'cas_2004_v03.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v03.tm',
#    'year': '2004-01-01'},
#   {'id': 395,
#    'mission': 'cassini',
#    'name': 'cas_2004_v02.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v02.tm',
#    'year': '2004-01-01'},
#   {'id': 396,
#    'mission': 'cassini',
#    'name': 'cas_2004_v01.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2004_v01.tm',
#    'year': '2004-01-01'},
#   {'id': 397,
#    'mission': 'cassini',
#    'name': 'cas_2015_v07.tm',
#    'newest': True,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2015_v07.tm',
#    'year': '2015-01-01'},
#   {'id': 398,
#    'mission': 'cassini',
#    'name': 'cas_2015_v06.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2015_v06.tm',
#    'year': '2015-01-01'},
#   {'id': 399,
#    'mission': 'cassini',
#    'name': 'cas_2015_v05.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2015_v05.tm',
#    'year': '2015-01-01'},
#   {'id': 400,
#    'mission': 'cassini',
#    'name': 'cas_2015_v04.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2015_v04.tm',
#    'year': '2015-01-01'},
#   {'id': 401,
#    'mission': 'cassini',
#    'name': 'cas_2015_v03.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2015_v03.tm',
#    'year': '2015-01-01'},
#   {'id': 402,
#    'mission': 'cassini',
#    'name': 'cas_2015_v02.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2015_v02.tm',
#    'year': '2015-01-01'},
#   {'id': 403,
#    'mission': 'cassini',
#    'name': 'cas_2015_v01.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2015_v01.tm',
#    'year': '2015-01-01'},
#   {'id': 404,
#    'mission': 'cassini',
#    'name': 'cas_1998_v21.tm',
#    'newest': True,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1998_v21.tm',
#    'year': '1998-01-01'},
#   {'id': 405,
#    'mission': 'cassini',
#    'name': 'cas_1998_v20.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1998_v20.tm',
#    'year': '1998-01-01'},
#   {'id': 406,
#    'mission': 'cassini',
#    'name': 'cas_1998_v19.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1998_v19.tm',
#    'year': '1998-01-01'},
#   {'id': 407,
#    'mission': 'cassini',
#    'name': 'cas_1998_v18.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1998_v18.tm',
#    'year': '1998-01-01'},
#   {'id': 408,
#    'mission': 'cassini',
#    'name': 'cas_1998_v17.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1998_v17.tm',
#    'year': '1998-01-01'},
#   {'id': 409,
#    'mission': 'cassini',
#    'name': 'cas_1998_v16.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1998_v16.tm',
#    'year': '1998-01-01'},
#   {'id': 410,
#    'mission': 'cassini',
#    'name': 'cas_1998_v15.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1998_v15.tm',
#    'year': '1998-01-01'},
#   {'id': 411,
#    'mission': 'cassini',
#    'name': 'cas_1998_v14.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1998_v14.tm',
#    'year': '1998-01-01'},
#   {'id': 412,
#    'mission': 'cassini',
#    'name': 'cas_1998_v13.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1998_v13.tm',
#    'year': '1998-01-01'},
#   {'id': 413,
#    'mission': 'cassini',
#    'name': 'cas_1998_v12.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1998_v12.tm',
#    'year': '1998-01-01'},
#   {'id': 414,
#    'mission': 'cassini',
#    'name': 'cas_1998_v11.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1998_v11.tm',
#    'year': '1998-01-01'},
#   {'id': 415,
#    'mission': 'cassini',
#    'name': 'cas_1998_v10.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1998_v10.tm',
#    'year': '1998-01-01'},
#   {'id': 416,
#    'mission': 'cassini',
#    'name': 'cas_1998_v09.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1998_v09.tm',
#    'year': '1998-01-01'},
#   {'id': 417,
#    'mission': 'cassini',
#    'name': 'cas_1998_v08.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1998_v08.tm',
#    'year': '1998-01-01'},
#   {'id': 418,
#    'mission': 'cassini',
#    'name': 'cas_1998_v07.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1998_v07.tm',
#    'year': '1998-01-01'},
#   {'id': 419,
#    'mission': 'cassini',
#    'name': 'cas_1998_v06.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1998_v06.tm',
#    'year': '1998-01-01'},
#   {'id': 420,
#    'mission': 'cassini',
#    'name': 'cas_1998_v05.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1998_v05.tm',
#    'year': '1998-01-01'},
#   {'id': 421,
#    'mission': 'cassini',
#    'name': 'cas_1998_v04.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1998_v04.tm',
#    'year': '1998-01-01'},
#   {'id': 422,
#    'mission': 'cassini',
#    'name': 'cas_1998_v03.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1998_v03.tm',
#    'year': '1998-01-01'},
#   {'id': 423,
#    'mission': 'cassini',
#    'name': 'cas_1998_v02.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1998_v02.tm',
#    'year': '1998-01-01'},
#   {'id': 424,
#    'mission': 'cassini',
#    'name': 'cas_1998_v01.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1998_v01.tm',
#    'year': '1998-01-01'},
#   {'id': 425,
#    'mission': 'cassini',
#    'name': 'cas_2012_v13.tm',
#    'newest': True,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2012_v13.tm',
#    'year': '2012-01-01'},
#   {'id': 426,
#    'mission': 'cassini',
#    'name': 'cas_2012_v12.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2012_v12.tm',
#    'year': '2012-01-01'},
#   {'id': 427,
#    'mission': 'cassini',
#    'name': 'cas_2012_v11.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2012_v11.tm',
#    'year': '2012-01-01'},
#   {'id': 428,
#    'mission': 'cassini',
#    'name': 'cas_2012_v10.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2012_v10.tm',
#    'year': '2012-01-01'},
#   {'id': 429,
#    'mission': 'cassini',
#    'name': 'cas_2012_v09.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2012_v09.tm',
#    'year': '2012-01-01'},
#   {'id': 430,
#    'mission': 'cassini',
#    'name': 'cas_2012_v08.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2012_v08.tm',
#    'year': '2012-01-01'},
#   {'id': 431,
#    'mission': 'cassini',
#    'name': 'cas_2012_v07.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2012_v07.tm',
#    'year': '2012-01-01'},
#   {'id': 432,
#    'mission': 'cassini',
#    'name': 'cas_2012_v06.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2012_v06.tm',
#    'year': '2012-01-01'},
#   {'id': 433,
#    'mission': 'cassini',
#    'name': 'cas_2012_v05.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2012_v05.tm',
#    'year': '2012-01-01'},
#   {'id': 434,
#    'mission': 'cassini',
#    'name': 'cas_2012_v04.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2012_v04.tm',
#    'year': '2012-01-01'},
#   {'id': 435,
#    'mission': 'cassini',
#    'name': 'cas_2012_v03.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2012_v03.tm',
#    'year': '2012-01-01'},
#   {'id': 436,
#    'mission': 'cassini',
#    'name': 'cas_2012_v02.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2012_v02.tm',
#    'year': '2012-01-01'},
#   {'id': 437,
#    'mission': 'cassini',
#    'name': 'cas_2012_v01.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2012_v01.tm',
#    'year': '2012-01-01'},
#   {'id': 438,
#    'mission': 'cassini',
#    'name': 'cas_2010_v17.tm',
#    'newest': True,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2010_v17.tm',
#    'year': '2010-01-01'},
#   {'id': 439,
#    'mission': 'cassini',
#    'name': 'cas_2010_v16.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2010_v16.tm',
#    'year': '2010-01-01'},
#   {'id': 440,
#    'mission': 'cassini',
#    'name': 'cas_2010_v15.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2010_v15.tm',
#    'year': '2010-01-01'},
#   {'id': 441,
#    'mission': 'cassini',
#    'name': 'cas_2010_v14.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2010_v14.tm',
#    'year': '2010-01-01'},
#   {'id': 442,
#    'mission': 'cassini',
#    'name': 'cas_2010_v13.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2010_v13.tm',
#    'year': '2010-01-01'},
#   {'id': 443,
#    'mission': 'cassini',
#    'name': 'cas_2010_v12.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2010_v12.tm',
#    'year': '2010-01-01'},
#   {'id': 444,
#    'mission': 'cassini',
#    'name': 'cas_2010_v11.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2010_v11.tm',
#    'year': '2010-01-01'},
#   {'id': 445,
#    'mission': 'cassini',
#    'name': 'cas_2010_v10.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2010_v10.tm',
#    'year': '2010-01-01'},
#   {'id': 446,
#    'mission': 'cassini',
#    'name': 'cas_2010_v09.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2010_v09.tm',
#    'year': '2010-01-01'},
#   {'id': 447,
#    'mission': 'cassini',
#    'name': 'cas_2010_v08.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2010_v08.tm',
#    'year': '2010-01-01'},
#   {'id': 448,
#    'mission': 'cassini',
#    'name': 'cas_2010_v07.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2010_v07.tm',
#    'year': '2010-01-01'},
#   {'id': 449,
#    'mission': 'cassini',
#    'name': 'cas_2010_v06.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2010_v06.tm',
#    'year': '2010-01-01'},
#   {'id': 450,
#    'mission': 'cassini',
#    'name': 'cas_2010_v05.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2010_v05.tm',
#    'year': '2010-01-01'},
#   {'id': 451,
#    'mission': 'cassini',
#    'name': 'cas_2010_v04.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2010_v04.tm',
#    'year': '2010-01-01'},
#   {'id': 452,
#    'mission': 'cassini',
#    'name': 'cas_2010_v03.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2010_v03.tm',
#    'year': '2010-01-01'},
#   {'id': 453,
#    'mission': 'cassini',
#    'name': 'cas_2010_v02.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2010_v02.tm',
#    'year': '2010-01-01'},
#   {'id': 454,
#    'mission': 'cassini',
#    'name': 'cas_2010_v01.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2010_v01.tm',
#    'year': '2010-01-01'},
#   {'id': 455,
#    'mission': 'cassini',
#    'name': 'cas_2006_v25.tm',
#    'newest': True,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2006_v25.tm',
#    'year': '2006-01-01'},
#   {'id': 456,
#    'mission': 'cassini',
#    'name': 'cas_2006_v24.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2006_v24.tm',
#    'year': '2006-01-01'},
#   {'id': 457,
#    'mission': 'cassini',
#    'name': 'cas_2006_v23.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2006_v23.tm',
#    'year': '2006-01-01'},
#   {'id': 458,
#    'mission': 'cassini',
#    'name': 'cas_2006_v22.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2006_v22.tm',
#    'year': '2006-01-01'},
#   {'id': 459,
#    'mission': 'cassini',
#    'name': 'cas_2006_v21.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2006_v21.tm',
#    'year': '2006-01-01'},
#   {'id': 460,
#    'mission': 'cassini',
#    'name': 'cas_2006_v20.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2006_v20.tm',
#    'year': '2006-01-01'},
#   {'id': 461,
#    'mission': 'cassini',
#    'name': 'cas_2006_v19.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2006_v19.tm',
#    'year': '2006-01-01'},
#   {'id': 462,
#    'mission': 'cassini',
#    'name': 'cas_2006_v18.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2006_v18.tm',
#    'year': '2006-01-01'},
#   {'id': 463,
#    'mission': 'cassini',
#    'name': 'cas_2006_v17.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2006_v17.tm',
#    'year': '2006-01-01'},
#   {'id': 464,
#    'mission': 'cassini',
#    'name': 'cas_2006_v16.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2006_v16.tm',
#    'year': '2006-01-01'},
#   {'id': 465,
#    'mission': 'cassini',
#    'name': 'cas_2006_v15.tm',
#    'newest': False,
# ...
#    'year': '2000-01-01'},
#   {'id': 522,
#    'mission': 'cassini',
#    'name': 'cas_2000_v22.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v22.tm',
#    'year': '2000-01-01'},
#   {'id': 523,
#    'mission': 'cassini',
#    'name': 'cas_2000_v21.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v21.tm',
#    'year': '2000-01-01'},
#   {'id': 524,
#    'mission': 'cassini',
#    'name': 'cas_2000_v20.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v20.tm',
#    'year': '2000-01-01'},
#   {'id': 525,
#    'mission': 'cassini',
#    'name': 'cas_2000_v19.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v19.tm',
#    'year': '2000-01-01'},
#   {'id': 526,
#    'mission': 'cassini',
#    'name': 'cas_2000_v18.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v18.tm',
#    'year': '2000-01-01'},
#   {'id': 527,
#    'mission': 'cassini',
#    'name': 'cas_2000_v17.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v17.tm',
#    'year': '2000-01-01'},
#   {'id': 528,
#    'mission': 'cassini',
#    'name': 'cas_2000_v16.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v16.tm',
#    'year': '2000-01-01'},
#   {'id': 529,
#    'mission': 'cassini',
#    'name': 'cas_2000_v15.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v15.tm',
#    'year': '2000-01-01'},
#   {'id': 530,
#    'mission': 'cassini',
#    'name': 'cas_2000_v14.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v14.tm',
#    'year': '2000-01-01'},
#   {'id': 531,
#    'mission': 'cassini',
#    'name': 'cas_2000_v13.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v13.tm',
#    'year': '2000-01-01'},
#   {'id': 532,
#    'mission': 'cassini',
#    'name': 'cas_2000_v12.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v12.tm',
#    'year': '2000-01-01'},
#   {'id': 533,
#    'mission': 'cassini',
#    'name': 'cas_2000_v11.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v11.tm',
#    'year': '2000-01-01'},
#   {'id': 534,
#    'mission': 'cassini',
#    'name': 'cas_2000_v10.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v10.tm',
#    'year': '2000-01-01'},
#   {'id': 535,
#    'mission': 'cassini',
#    'name': 'cas_2000_v09.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v09.tm',
#    'year': '2000-01-01'},
#   {'id': 536,
#    'mission': 'cassini',
#    'name': 'cas_2000_v08.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v08.tm',
#    'year': '2000-01-01'},
#   {'id': 537,
#    'mission': 'cassini',
#    'name': 'cas_2000_v07.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v07.tm',
#    'year': '2000-01-01'},
#   {'id': 538,
#    'mission': 'cassini',
#    'name': 'cas_2000_v06.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v06.tm',
#    'year': '2000-01-01'},
#   {'id': 539,
#    'mission': 'cassini',
#    'name': 'cas_2000_v05.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v05.tm',
#    'year': '2000-01-01'},
#   {'id': 540,
#    'mission': 'cassini',
#    'name': 'cas_2000_v04.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v04.tm',
#    'year': '2000-01-01'},
#   {'id': 541,
#    'mission': 'cassini',
#    'name': 'cas_2000_v03.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v03.tm',
#    'year': '2000-01-01'},
#   {'id': 542,
#    'mission': 'cassini',
#    'name': 'cas_2000_v02.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v02.tm',
#    'year': '2000-01-01'},
#   {'id': 543,
#    'mission': 'cassini',
#    'name': 'cas_2000_v01.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2000_v01.tm',
#    'year': '2000-01-01'},
#   {'id': 544,
#    'mission': 'cassini',
#    'name': 'cas_1999_v21.tm',
#    'newest': True,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1999_v21.tm',
#    'year': '1999-01-01'},
#   {'id': 545,
#    'mission': 'cassini',
#    'name': 'cas_1999_v20.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1999_v20.tm',
#    'year': '1999-01-01'},
#   {'id': 546,
#    'mission': 'cassini',
#    'name': 'cas_1999_v19.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1999_v19.tm',
#    'year': '1999-01-01'},
#   {'id': 547,
#    'mission': 'cassini',
#    'name': 'cas_1999_v18.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1999_v18.tm',
#    'year': '1999-01-01'},
#   {'id': 548,
#    'mission': 'cassini',
#    'name': 'cas_1999_v17.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1999_v17.tm',
#    'year': '1999-01-01'},
#   {'id': 549,
#    'mission': 'cassini',
#    'name': 'cas_1999_v16.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1999_v16.tm',
#    'year': '1999-01-01'},
#   {'id': 550,
#    'mission': 'cassini',
#    'name': 'cas_1999_v15.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1999_v15.tm',
#    'year': '1999-01-01'},
#   {'id': 551,
#    'mission': 'cassini',
#    'name': 'cas_1999_v14.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1999_v14.tm',
#    'year': '1999-01-01'},
#   {'id': 552,
#    'mission': 'cassini',
#    'name': 'cas_1999_v13.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1999_v13.tm',
#    'year': '1999-01-01'},
#   {'id': 553,
#    'mission': 'cassini',
#    'name': 'cas_1999_v12.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1999_v12.tm',
#    'year': '1999-01-01'},
#   {'id': 554,
#    'mission': 'cassini',
#    'name': 'cas_1999_v11.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1999_v11.tm',
#    'year': '1999-01-01'},
#   {'id': 555,
#    'mission': 'cassini',
#    'name': 'cas_1999_v10.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1999_v10.tm',
#    'year': '1999-01-01'},
#   {'id': 556,
#    'mission': 'cassini',
#    'name': 'cas_1999_v09.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1999_v09.tm',
#    'year': '1999-01-01'},
#   {'id': 557,
#    'mission': 'cassini',
#    'name': 'cas_1999_v08.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1999_v08.tm',
#    'year': '1999-01-01'},
#   {'id': 558,
#    'mission': 'cassini',
#    'name': 'cas_1999_v07.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1999_v07.tm',
#    'year': '1999-01-01'},
#   {'id': 559,
#    'mission': 'cassini',
#    'name': 'cas_1999_v06.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1999_v06.tm',
#    'year': '1999-01-01'},
#   {'id': 560,
#    'mission': 'cassini',
#    'name': 'cas_1999_v05.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1999_v05.tm',
#    'year': '1999-01-01'},
#   {'id': 561,
#    'mission': 'cassini',
#    'name': 'cas_1999_v04.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1999_v04.tm',
#    'year': '1999-01-01'},
#   {'id': 562,
#    'mission': 'cassini',
#    'name': 'cas_1999_v03.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1999_v03.tm',
#    'year': '1999-01-01'},
#   {'id': 563,
#    'mission': 'cassini',
#    'name': 'cas_1999_v02.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1999_v02.tm',
#    'year': '1999-01-01'},
#   {'id': 564,
#    'mission': 'cassini',
#    'name': 'cas_1999_v01.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_1999_v01.tm',
#    'year': '1999-01-01'},
#   {'id': 565,
#    'mission': 'cassini',
#    'name': 'cas_2001_v24.tm',
#    'newest': True,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v24.tm',
#    'year': '2001-01-01'},
#   {'id': 566,
#    'mission': 'cassini',
#    'name': 'cas_2001_v23.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v23.tm',
#    'year': '2001-01-01'},
#   {'id': 567,
#    'mission': 'cassini',
#    'name': 'cas_2001_v22.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v22.tm',
#    'year': '2001-01-01'},
#   {'id': 568,
#    'mission': 'cassini',
#    'name': 'cas_2001_v21.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v21.tm',
#    'year': '2001-01-01'},
#   {'id': 569,
#    'mission': 'cassini',
#    'name': 'cas_2001_v20.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v20.tm',
#    'year': '2001-01-01'},
#   {'id': 570,
#    'mission': 'cassini',
#    'name': 'cas_2001_v19.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v19.tm',
#    'year': '2001-01-01'},
#   {'id': 571,
#    'mission': 'cassini',
#    'name': 'cas_2001_v18.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v18.tm',
#    'year': '2001-01-01'},
#   {'id': 572,
#    'mission': 'cassini',
#    'name': 'cas_2001_v17.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v17.tm',
#    'year': '2001-01-01'},
#   {'id': 573,
#    'mission': 'cassini',
#    'name': 'cas_2001_v16.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v16.tm',
#    'year': '2001-01-01'},
#   {'id': 574,
#    'mission': 'cassini',
#    'name': 'cas_2001_v15.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v15.tm',
#    'year': '2001-01-01'},
#   {'id': 575,
#    'mission': 'cassini',
#    'name': 'cas_2001_v14.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v14.tm',
#    'year': '2001-01-01'},
#   {'id': 576,
#    'mission': 'cassini',
#    'name': 'cas_2001_v13.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v13.tm',
#    'year': '2001-01-01'},
#   {'id': 577,
#    'mission': 'cassini',
#    'name': 'cas_2001_v12.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v12.tm',
#    'year': '2001-01-01'},
#   {'id': 578,
#    'mission': 'cassini',
#    'name': 'cas_2001_v11.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v11.tm',
#    'year': '2001-01-01'},
#   {'id': 579,
#    'mission': 'cassini',
#    'name': 'cas_2001_v10.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v10.tm',
#    'year': '2001-01-01'},
#   {'id': 580,
#    'mission': 'cassini',
#    'name': 'cas_2001_v09.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v09.tm',
#    'year': '2001-01-01'},
#   {'id': 581,
#    'mission': 'cassini',
#    'name': 'cas_2001_v08.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v08.tm',
#    'year': '2001-01-01'},
#   {'id': 582,
#    'mission': 'cassini',
#    'name': 'cas_2001_v07.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v07.tm',
#    'year': '2001-01-01'},
#   {'id': 583,
#    'mission': 'cassini',
#    'name': 'cas_2001_v06.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v06.tm',
#    'year': '2001-01-01'},
#   {'id': 584,
#    'mission': 'cassini',
#    'name': 'cas_2001_v05.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v05.tm',
#    'year': '2001-01-01'},
#   {'id': 585,
#    'mission': 'cassini',
#    'name': 'cas_2001_v04.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v04.tm',
#    'year': '2001-01-01'},
#   {'id': 586,
#    'mission': 'cassini',
#    'name': 'cas_2001_v03.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v03.tm',
#    'year': '2001-01-01'},
#   {'id': 587,
#    'mission': 'cassini',
#    'name': 'cas_2001_v02.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v02.tm',
#    'year': '2001-01-01'},
#   {'id': 588,
#    'mission': 'cassini',
#    'name': 'cas_2001_v01.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2001_v01.tm',
#    'year': '2001-01-01'},
#   {'id': 589,
#    'mission': 'cassini',
#    'name': 'cas_2016_v05.tm',
#    'newest': True,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2016_v05.tm',
#    'year': '2016-01-01'},
#   {'id': 590,
#    'mission': 'cassini',
#    'name': 'cas_2016_v04.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2016_v04.tm',
#    'year': '2016-01-01'},
#   {'id': 591,
#    'mission': 'cassini',
#    'name': 'cas_2016_v03.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2016_v03.tm',
#    'year': '2016-01-01'},
#   {'id': 592,
#    'mission': 'cassini',
#    'name': 'cas_2016_v02.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2016_v02.tm',
#    'year': '2016-01-01'},
#   {'id': 593,
#    'mission': 'cassini',
#    'name': 'cas_2016_v01.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2016_v01.tm',
#    'year': '2016-01-01'},
#   {'id': 594,
#    'mission': 'cassini',
#    'name': 'cas_2014_v07.tm',
#    'newest': True,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2014_v07.tm',
#    'year': '2014-01-01'},
#   {'id': 595,
#    'mission': 'cassini',
#    'name': 'cas_2014_v06.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2014_v06.tm',
#    'year': '2014-01-01'},
#   {'id': 596,
#    'mission': 'cassini',
#    'name': 'cas_2014_v05.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2014_v05.tm',
#    'year': '2014-01-01'},
#   {'id': 597,
#    'mission': 'cassini',
#    'name': 'cas_2014_v04.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2014_v04.tm',
#    'year': '2014-01-01'},
#   {'id': 598,
#    'mission': 'cassini',
#    'name': 'cas_2014_v03.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2014_v03.tm',
#    'year': '2014-01-01'},
#   {'id': 599,
#    'mission': 'cassini',
#    'name': 'cas_2014_v02.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2014_v02.tm',
#    'year': '2014-01-01'},
#   {'id': 600,
#    'mission': 'cassini',
#    'name': 'cas_2014_v01.tm',
#    'newest': False,
#    'path': '/data/spice/co-s_j_e_v-spice-6-v1.0/cosp_1000/extras/mk/cas_2014_v01.tm',
#    'year': '2014-01-01'}],
#  'success': True}

# %% [markdown]
# ## Example generation of the ISD object
#
# Notice that every endpoint returns with a `success` key and a `data` key at the top level.  This helps the user know if the call was successful and that all of the response is within the `data` key.

# %%
data
# Out:
# '{"target_name": "ENCELADUS", "capture_date": "2015-12-19T17:34:38.317000", "instrument": "IMAGING SCIENCE SUBSYSTEM - NARROW ANGLE", "spacecraft_id": "CASSINI ORBITER", "spacecraft_clock_count": "1829241512.246", "exposure_duration": 1500.0, "lighttime_correction": "LT+S", "min_elevation": -100, "max_elevation": 100}'

# %%
r = requests.post('http://smalls:8002/api/1.0/missions/cassini/csm_isd', data=data)
r.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-13-569615d636e5> in <module>()
#       1 r = requests.post('http://smalls:8002/api/1.0/missions/cassini/csm_isd', data=data)
# ----> 2 r.json()
#
# ~/anaconda3/envs/ct/lib/python3.6/site-packages/requests/models.py in json(self, **kwargs)
#     890                     # used.
#     891                     pass
# --> 892         return complexjson.loads(self.text, **kwargs)
#     893
#     894     @property
#
# ~/anaconda3/envs/ct/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# ~/anaconda3/envs/ct/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# ~/anaconda3/envs/ct/lib/python3.6/json/decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# ## Use the ISD

# %%
import usgscam as cam
from cycsm.isd import Isd

# %%
isd = r.json()['data']['isd']

# %%
i = Isd.loads(isd)

# %%
plugin = cam.mdis.MdisPlugin()
camera = plugin.from_isd(i, plugin.modelname(0))

# %%
camera.imagesize
# Out:
# (1024.0, 1024.0)

# %%
xyz = camera.imageToGround(512, 512, 0)
xyz
# Out:
# [232745.39404384792, 108032.64063985727, 1416.4229696467519]

# %%
camera.name
# Out:
# 'MDISNAC_USGSAstro_1_Linux64_csm30.so'

# %%
camera.groundToImage(0,0,0)
# Out:
# [512.0, 512.0]

# %% [markdown]
# ## Random Messenger Image
#
# The above could be perceived as being too canned.  Here, pull a random image from the PDS and instantiate a camera model.

# %%
from ftplib import FTP
import os
from random import choice

# %%
# Run only once to avoid too many open FTP connections
ftp = FTP('pdsimage2.wr.usgs.gov')
ftp.login()
dirs = ftp.nlst('archive/mess-e_v_h-mdis-2-edr-rawdata-v1.0/MSGRMDS_1001/DATA/')

# %%
data_dir = choice(dirs)
f = choice(ftp.nlst(data_dir))
fname = os.path.basename(f)
with open('/data/messenger_sample/{}'.format(fname), 'wb') as file:
    ftp.retrbinary('RETR {}'.format(f), file.write)

# %%
newfile = os.path.join('/data/messenger_sample/{}'.format(fname))

# %%
# Simple helper function to use the API
def create_data_pacakge(in_file):
    label = pvl.load(in_file)
    data = {'target_name': label['TARGET_NAME'],
            'capture_date': label['START_TIME'].isoformat(),
            'instrument': label['INSTRUMENT_NAME'], 
            'focal_plane_temperature': label['FOCAL_PLANE_TEMPERATURE'].value,
            'spacecraft_id' : label['INSTRUMENT_HOST_NAME'],
            'spacecraft_clock_count': label['SPACECRAFT_CLOCK_START_COUNT'],
            'exposure_duration': label['EXPOSURE_DURATION'].value,
            'lighttime_correction':'LT+S', 
            'min_elevation': -100,
            'max_elevation': 100,
            }
    return json.dumps(data)

print('Processing a new image: {}'.format(newfile))

# Call the func to create the data package for submission to the micro-service
data = create_data_pacakge(newfile)

# Call the micro-service
r = requests.post('http://localhost:5000/api/1.0/csm_isd', data=data)

# Get the ISD back and instantiate a local ISD for the image
isd = r.json()['data']['isd']
i = Isd.loads(isd)

# Create the plugin and camera as usual
plugin = cam.mdis.MdisPlugin()
camera = plugin.from_isd(i, plugin.modelname(0))

# Call I2G
xyz = camera.imageToGround(512.5, 512.5, 0)
print(xyz)

# Call G2I
camera.groundToImage(*xyz)
# Out:
# Processing a new image: /data/messenger_sample/EW1012946978D.IMG
# [-722219.633387954, 583190.2862394641, 2255872.392486973]
# [512.5000000007078, 512.4999999999983]
